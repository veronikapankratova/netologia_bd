# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
len(long_phrase)> len(short_phrase)

# %%
#Дано значение объема файла в байтах (в мегабайте 2^20 байт). 
#Напишите перевод этого значения в мегабайты в формате: "Объем файла равен 213.68Mb".
print('введите количество байт')
bait=int(input(''))
megabait=bait/2**20
print(megabait)
print('Объем файла равен',str(megabait),'Mb')

# %%
#Задание 3. Разработать приложение для определения знака зодиака по дате рождения. Пример:

#Введите месяц: март

#Введите число: 6

print('insert your month')
my_months=input('')

print("ваш месяц:", my_months)
print('введите Ваше число')
my_date = int(input(''))
type(my_date)

print('Ваше число', int(my_date))
count_number=0
months={
    "январь":0, 
    'февраль':31
}
for elem, value in months.items():
#     print (value)
    if my_months == elem:
        count_number +=  value 
        сount_number_new = count_number +my_date
#         print (сount_number_new)
    
zodiak={
    'kozerog': range(1,21),
    'vodoliy': range(22,45),
    'riby': range(46,76)}
# print(zodiak)
for  element, values in zodiak.items():
#      f = list(values[])
#         print (f)
    if сount_number_new in values:
        print (element)

# # # date=range(0,31)
# # #zodiak=["рыбы", овен, лев, рак]

# # #print(months)''
# # 
# # for elements in months.values():
# # if my_months in month.keys():
# #     count_date = elementя
# Out:
# insert your month
# январь
# ваш месяц: январь
# введите Ваше число
# 12
# Ваше число 12
# kozerog

# %%
Задание 4. Нужно разработать приложение для финансового планирования. Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию. Пользователь вводит:

    заработанную плату в месяц.
    сколько процентов от ЗП уходит на ипотеку.
    сколько процентов от ЗП уходит "на жизнь".
    сколько раз приходит премия в год.

Остальная часть заработанной платы откладывается на пенсию.

Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.

Программа должна учитывать сколько премий было в год.

Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.

Пример:

Введите заработанную плату в месяц: 100000

Введите сколько процентов уходит на ипотеку: 30

Введите сколько процентов уходит на жизнь: 50

Введите количество премий за год: 2


Вывод: На ипотеку было потрачено: 360000 рублей Было накоплено: 340000 рублей

# %%
print('Введите заработанную плату в месяц:')
my_salary=int(input(''))
print('Введите сколько процентов уходит на ипотеку:')
my_interest=int(input(''))
print('Введите сколько процентов уходит на жизнь')
my_interest_life=int(input(''))
print('Введите количество премий за год:')
my_reward_count=int(input(''))
my_reward=my_reward_count*my_salary
#print(my_reward)
my_expenses=my_salary*12*(my_interest_life+my_interest)/100+my_reward/2
my_savings=my_salary*12-my_expenses
print('На ипотеку было потрачено:',my_expenses, 'рублей')
print('Было накоплено:',my_savings,'рублей')

# %% [markdown]
#               ##ДОМАШНЕЕ ЗАДАНИЕ 2

# %%
# Задача 1. Дано слово из латинских букв. Напишите скрипт, который выводит на экран букву из середины слова (если число букв нечетное). Если букв четное число, то на экран выводятся две буквы из середины.

# Пример: для 'test' должно выводится 'es', для 'testing' - 't'


print('введите слово:')
my_word=str(input(''))
len(my_word)
list_new=[]
for i  in my_word:
    list_new.append (i)
print(list_new)
    
if len(list_new)%2==0:
    while len(list_new) != 2:
        del(list_new[0])
        del(list_new[-1])    
#     del(list_new[-1])
    print(list_new)
else:
    while len(list_new) != 3:
        del(list_new[0])
        del(list_new[-1])    
#     del(list_new[-1])
    print(list_new)
# enumerate(my_word)

# del(my_new_word[0])
# print (my_new_word)
#         while len(my_new_word) ==2:
#             del(my_new_word[0])
#             del(my_new_word[-1])
#             print(my_new_word)
# # else:
#     while len(my_word)==1:
#         del(my_word[-1]) 
#         del(my_word[-0])
#     print(my_word)

# %%
# Задача 2. Мы делаем MVP dating-сервиса, и у нас есть список парней и девушек (их число может варьироваться):
# In [9]:

# boys = ['Peter', 'Alex', 'John', 'Arthur', 'Richard']
# girls = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']

# Выдвигаем гипотезу: лучшие рекомендации мы получим, если просто отсортируем имена по алфавиту и познакомим людей с одинаковыми индексами после сортировки! "Познакомить" пары нам поможет функция zip, а в цикле распакуем zip-объект и выведем информацию в виде:

# Идеальные пары:
# Alex и Emma
# Arthur и Kate
# John и Kira
# Peter и Liza
# Richard и Trisha

# Внимание! Если количество людей в списках будет не совпадать, то мы никого знакомить не будет и выведем пользователю предупрежде

# ние, что кто-то может остаться без пары!

boys = ['Peter', 'Alex', 'John', 'Arthur', 'Richard']
girls = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']

print(len(boys))
len(girls)
if len(boys)!= len(girls):  
         print('ничего не нашлось')
else:    
        para = zip (boys,girls)
        print('идеальные пары')
        print(list(para))

# %%
# адача 3. У нас есть список, содержащий информацию о среднедневной температуре в Фаренгейтах за недельный период по странам.
# Необходимо написать код, который рассчитает среднюю температуру за неделю в Цельсиях для каждой страны.
# In [4]:

country_temperature = [
 ['Thailand', [75.2, 77, 78.8, 73.4, 68, 75.2, 77]],
 ['Germany', [57.2, 55.4, 59, 59, 53.6, 55.4, 57.2]],
 ['Russia', [35.6, 37.4, 39.2, 41, 42.8, 39.2, 35.6]],
 ['Poland', [50, 50, 53.6, 57.2, 55.4, 55.4, 51.8]],
]
for item in country_temperature:
    print((item[0]), sum(item[1])/7)

# %%
# Задача 4. Дан поток логов по количеству просмотренных страниц для каждого пользователя. 
# Список отсортирован по ID пользователя. Вам необходимо написать алгоритм, 
# который считает среднее значение просмотров на пользователя. 
# Т. е. надо посчитать отношение суммы всех просмотров к количеству уникальных пользователей.
# In [2]:


steam=[
    '2018-01-01 , user1,3',
    '2018-01-07,user1,4',
    '2018-03-29,user1,1',
    '2018-04-04,user1,13',
    '2018-01-05,user2,7',
    '2018-06-14,user3,4',
    '2018-07-02,user3,10',
    '2018-03-21,user4,19',
    '2018-03-22,user4,4',
    '2018-04-22,user4,8',
    '2018-05-03,user4,9',
    '2018-05-11,user4,11',
]
steam_currect = []
stem_new =[]
       
for elements in steam:
        steam_currect.append (elements.split(','))
print (steam_currect)

for element in steam_currect:
       print(element)
for element in steam_currect:
#     
    del(element[0])
print (steam_currect)

steam_user1 = []
steam_user2 = []
steam_user3 = []
steam_user4 = []
for element in steam_currect:
    if 'user1' in element:
        steam_user1.append (int(element[1]))
print ('количество посещение пользователя 1')
# print (steam_user1)
print (sum(steam_user1 ) /len(steam_currect))
#         sum([steam_user1])
#     elif 'user2' in element:
#         steam_user2.append (int(element[1]))
# print ('количество посещение пользователя 2')
# print (steam_user2)
# print (sum(steam_user2 ) /len(steam_currect))
#     if 'user3' in element:
#         steam_user3.append (element[1])
# print ('user3' ,steam_user3)
#     elif 'user4' in element:
#         steam_user4.append (element[1])
# print ('user4' ,steam_user4)

# %%
# адача 5. Дана статистика рекламных кампаний по дням. 
# Напишите алгоритм, который по паре дата-кампания ищет значение численного столбца. 
# Т. е. для даты '2018-01-01' и 'google' нужно получить число 25. 
# Считайте, что все комбинации дата-кампания уникальны.
# In [12]:

# %%
stats = [
    ['2018-01-01', 'google', 25],
    ['2018-01-01', 'yandex', 65],
    ['2018-01-01', 'market', 89],
    ['2018-01-02', 'google', 574],
    ['2018-01-02', 'yandex', 249],
    ['2018-01-02', 'market', 994],
    ['2018-01-03', 'google', 1843],
    ['2018-01-03', 'yandex', 1327],
    ['2018-01-03', 'market', 1764],
]

print('укажите дату')
date=(input(''))
print('укажите компанию')
company=(input(''))
spisok=[]

spisok_new = []
for k in stats:
#     print (k)
    if date in k[0]:
        spisok.append(k)
# print(spisok)
for p in spisok:
#     print (p)
    if company in p[1]:
        spisok_new.append(p) 
print (spisok_new)
spisok_new[0][2]
            
#     else:
#         print ('ничего не найдено')

# %%
# адача 6. Дан список вида:
# In [1]:

data = [
    [13, 25, 23, 34],
    [45, 32, 44, 47],
    [12, 33, 23, 95],
    [13, 53, 34, 35]
]

# Напишите код, который будет вычислять сумму элементов на диагонали. Т. е. 13+32+23+35.
# Список может быть любой длины, но всегда является "квадратным" (количество элементов во вложенных списках равно их количеству).

list(enumerate(data))
amount = []
for i, element in enumerate(data):
    amount.append ([element[i]])
print(amount)
sum([element[i] for element in data])

# %% [markdown]
# ## домашнее задание 3

# %%
# адание 1. Дан список с визитами по городам и странам. Напишите код, который возвращает отфильтрованный список geo_logs,
# содержащий только визиты из России.
# In [9]:

geo_logs = [
    {'visit1': ['Москва', 'Россия']},
    {'visit2': ['Дели', 'Индия']},
    {'visit3': ['Владимир', 'Россия']},
    {'visit4': ['Лиссабон', 'Португалия']},
    {'visit5': ['Париж', 'Франция']},
    {'visit6': ['Лиссабон', 'Португалия']},
    {'visit7': ['Тула', 'Россия']},
    {'visit8': ['Тула', 'Россия']},
    {'visit9': ['Курск', 'Россия']},
    {'visit10': ['Архангельск', 'Россия']}
]

rus = 'Россия'

for elements in geo_logs:
    dict_elements = (elements)
#     print(dict_elements)

for values in dict_elements.items():
    if rus in values:
         print(list(values))

# %%
# Задание 2. Выведите на экран все уникальные гео-ID из значений словаря ids. Т. е. список вида [213, 15, 54, 119, 98, 35]
# In [4]:

ids = {'user1': [213, 213, 213, 15, 213], 
       'user2': [54, 54, 119, 119, 119], 
       'user3': [213, 98, 98, 35]}
ids_new =[]
ids_noviy =[]
ids_set=[]

for elements, values in ids.items():
#     print (elements)
    ids_new.append(values)
    
for i , z in enumerate(ids_new):
#     print (i,z)
    ids_set.append (set(z))
#     set(ids_set) 
#     print (list(ids_set))
for value in ids_set:
    ids_noviy+=value
    d=set(ids_noviy)
print(d)
    
# #     new_set=set([ids_set])
# ids_new_new=set(ids_new)

# %%
# Задание 3. Дан список поисковых запросов. Получить распределение количества слов в них. 
# Т. е. поисковых запросов из одного - слова 5%, из двух - 7%, из трех - 3% и т.д.
# In [1]:

queries = [
    'смотреть сериалы онлайн',
    'новости спорта',
    'афиша кино',
    'курс доллара',
    'сериалы этим летом',
    'курс по питону',
    'сериалы про спорт',
]
queries_count = []
numbers = []

for elements in queries:
        queries_count.append (elements.split(' '))
print (queries_count)

for x in queries_count:
    y = len(x)
    numbers.append(y)
print (numbers)
for z in numbers:
    w = numbers.count(z)
    t = f"количество слов в запросе, {z}, составило {w/len(numbers)*100} процентов"
    
    print (t)

# %%
# адание 4. Дана статистика рекламных каналов по объемам продаж. Напишите скрипт, который возвращает название канала с максимальным объемом. Т. е. в данном примере скрипт должен возвращать 'yandex'.
# In [8]:

stats = {'facebook': 55, 'yandex': 120, 'vk': 115, 'google': 99, 'email': 42, 'ok': 98}
list_name =[]
for keys, values in stats.items():
#         print (values)
        list_name.append (values)
#         max([x for x in values])
x = max(list_name)

# print (x)

for key,values in  stats.items():
    if x == values:
        print (key)

# %%
# Задание 5. Напишите код для преобразования произвольного списка вида ['2018-01-01', 'yandex', 'cpc', 100] 
# (он может быть любой длины) в словарь {'2018-01-01': {'yandex': {'cpc': 100}}}

def dict_turn_list(list_):
    i=0
    for i in enumerate (list_):
        print(list_[i])
    return

# %%
list_4= ['2018-01-01', 'yandex', 'cpc', 100]
# dict_dd = dict[(list)]
i=0
j=0

# while i != len(list_4):
# #     print(s)
for i,s in enumerate(list_4):
     print(i, s)
# while i!=len(list_4)
#  dict_new
dict_new= {list_4[0]:{list_4[1]:{list_4[2]:list_4[3]}} for s in list_4}
dict_new_new ={list_4[i]:{list_4[i+1]} for i in range(0,len(list_4))}
# for value in dict_new.values():
#     value={list_4[1]:list_4[2:]}
print (dict_new)

# return
# dict_turn_list(list_4)
# Out:
# 0 2018-01-01
# 1 yandex
# 2 cpc
# 3 100
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-77-84e630643165> in <module>
#      11 #  dict_new
#      12 dict_new= {list_4[0]:{list_4[1]:{list_4[2]:list_4[3]}} for s in list_4}
# ---> 13 dict_new_new ={list_4[i]:{list_4[i+1]} for i in range(0,len(list_4))}
#      14 # for value in dict_new.values():
#      15 #     value={list_4[1]:list_4[2:]}
#
# <ipython-input-77-84e630643165> in <dictcomp>(.0)
#      11 #  dict_new
#      12 dict_new= {list_4[0]:{list_4[1]:{list_4[2]:list_4[3]}} for s in list_4}
# ---> 13 dict_new_new ={list_4[i]:{list_4[i+1]} for i in range(0,len(list_4))}
#      14 # for value in dict_new.values():
#      15 #     value={list_4[1]:list_4[2:]}
#
# IndexError: list index out of range

# %%
def list_into_dict (list_):
    for i,s in elumerate(list_into_dict)
    print (i,s)
# Out:
#   File "<ipython-input-1-f5dbf9667282>", line 2
#     for i,s in elumerate(list_into_dict)
#                                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # функции

# %% [markdown]
# ы работаете секретарем и вам постоянно приходят различные документы.
# Вы должны быть очень внимательны, чтобы не потерять ни один документ. Каталог документов хранится в следующем виде:
#
# In [4]:
# documents = [
#     {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
#     {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
#     {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
# ]
# Перечень полок, на которых находятся документы хранится в следующем виде:
#
# In [5]:
# directories = {
#     '1': ['2207 876234', '11-2'],
#     '2': ['10006'],
#     '3': []
# }
# Необходимо реализовать пользовательские команды (внимание! это не название функций, которые должны быть выразительными, а команды, которые вводит пользователь, чтобы получить необходимый результат):
#
# p – people – команда, которая спросит номер документа и выведет имя человека, которому он принадлежит;
# s – shelf – команда, которая спросит номер документа и выведет номер полки, на которой он находится
# Правильно обработайте ситуации, когда пользователь будет вводить несуществующий документ.
# l – list – команда, которая выведет список всех документов в формате
# passport "2207 876234" "Василий Гупкин"
# as – add shelf – команда, которая спросит номер новой полки и добавит ее в перечень. Предусмотрите случай, когда пользователь добавляет полку, которая уже существует.
# d – delete – команда, которая спросит номер документа и удалит его из каталога и из перечня полок. Предусмотрите сценарий, когда пользователь вводит несуществующий документ;
# m – move – команда, которая спросит номер документа и целевую полку и переместит его с текущей полки на целевую. Корректно обработайте кейсы, когда пользователь пытается переместить несуществующий документ или переместить документ на несуществующую полку;
# a – add – команда, которая добавит новый документ в каталог и в перечень полок, спросив его номер, тип, имя владельца и номер полки, на котором он будет храниться. Корректно обработайте ситуацию, когда пользователь будет пытаться добавить документ на несуществующую полку.

# %%
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]
pas= 'passport'
# def people():
for elements in documents:
        for keys, values in elements.items():
            print(keys)
#     elements['type']['name']
#      for key,values in  stats.items():
            if x == values:
            elements['number']       
#             print ('ddfljdf', keys['type'])
# Out:
#   File "<ipython-input-110-343054f9dce9>", line 14
#     elements['number']
#            ^
# IndentationError: expected an indented block
